# %% [markdown]
# <a href="https://colab.research.google.com/github/DaffaPoseidon/PythonJobsheet8Semester4/blob/main/Jobsheet8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("data.csv")
dataset
# Out:
#    Person ID    Age       Income  ... Unnamed: 35 Unnamed: 36 Unnamed: 37
# 0          1  25-30         High  ...         NaN         NaN         NaN
# 1          2  25-30         High  ...         NaN         NaN         NaN
# 2          3  31-40         High  ...         NaN         NaN         NaN
# 3          4    >40       Medium  ...         NaN         NaN         NaN
# 4          5    >40          Low  ...         NaN         NaN         NaN
# 5          6  31-40          Low  ...         NaN         NaN         NaN
# 6          7  31-40       Medium  ...         NaN         NaN         NaN
# 7          8  25-30          Low  ...         NaN         NaN         NaN
# 8          9    >40       Medium  ...         NaN         NaN         NaN
# 9         10    >40         High  ...         NaN         NaN         NaN
# 10        11  25-30       Medium  ...         NaN         NaN         NaN
# 11        12  25-30       Medium  ...         NaN         NaN         NaN
# ...

# %%
X = dataset.iloc[:,:-1]
X
# Out:
#    Person ID    Age       Income  ... Unnamed: 34 Unnamed: 35 Unnamed: 36
# 0          1  25-30         High  ...         NaN         NaN         NaN
# 1          2  25-30         High  ...         NaN         NaN         NaN
# 2          3  31-40         High  ...         NaN         NaN         NaN
# 3          4    >40       Medium  ...         NaN         NaN         NaN
# 4          5    >40          Low  ...         NaN         NaN         NaN
# 5          6  31-40          Low  ...         NaN         NaN         NaN
# 6          7  31-40       Medium  ...         NaN         NaN         NaN
# 7          8  25-30          Low  ...         NaN         NaN         NaN
# 8          9    >40       Medium  ...         NaN         NaN         NaN
# 9         10    >40         High  ...         NaN         NaN         NaN
# 10        11  25-30       Medium  ...         NaN         NaN         NaN
# 11        12  25-30       Medium  ...         NaN         NaN         NaN
# ...

# %%
Y = dataset.iloc[:,4]
Y
# Out:
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes
# 5            Yes
# 6            Yes
# 7            Yes
# 8             No
# 9            Yes
# 10           Yes
# 11            No
# 12           NaN
# 13           NaN
# 14    hipertensi
# 15            ya
# 16         tidak
# 17         tidak
# 18         tidak
# 19            ya
# 20         tidak
# 21            ya
# 22         tidak
# 23           NaN
# 24           NaN
# 25      GANGGUAN
# 26      GANGGUAN
# 27        NORMAL
# 28      GANGGUAN
# 29        NORMAL
# 30        NORMAL
# 31        NORMAL
# 32      GANGGUAN
# 33        NORMAL
# 34        NORMAL
# 35        NORMAL
# 36        NORMAL
# 37        NORMAL
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# Name: Buys Car, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X = X.apply(LabelEncoder().fit_transform)
X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-466240a9cfd7> in <module>()
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
regressor = DecisionTreeClassifier()
regressor.fit(X.iloc[:,1:4], Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-d32e7c458ebc> in <module>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 regressor = DecisionTreeClassifier()
# ----> 3 regressor.fit(X.iloc[:,1:4], Y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
# ...

# %%
X_in = np.array([1,1,0])
Y_pred = regressor.predict([X_in])
Y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-6fe35c1b07ce> in <module>()
#       1 X_in = np.array([1,1,0])
# ----> 2 Y_pred = regressor.predict([X_in])
#       3 Y_pred
#
# NameError: name 'regressor' is not defined

# %%
from sklearn.externals.six import StringIO
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
from IPython.display import Image
from sklearn. tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(regressor, out_file = dot_data, filled = True, rounded = True, special_characters = True)
graph = pydotplus.graph_from_dot_data(dot_data.getValue())
graph.write_png('tree.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-32d3a2923152> in <module>()
#       3 import pydotplus
#       4 dot_data = StringIO()
# ----> 5 export_graphviz(regressor, out_file = dot_data, filled = True, rounded = True, special_characters = True)
#       6 graph = pydotplus.graph_from_dot_data(dot_data.getValue())
#       7 graph.write_png('tree.png')
#
# NameError: name 'regressor' is not defined
